# %%
import bs4 as bs
import urllib. request
import time
from datetime import datetime
import pandas as pd
import json
import os
import pandas as pd

# %% [markdown]
# # Scraping all rental data
#
# # Scraping entire data may take over 18 hours

# %%
def scrape_immobili(type_house,max_pages):
    for seite in range(1,max_pages):
    
        print("Loop " + str(seite) + " startet.")

        df = pd.DataFrame()
        l=[]

        try:

            soup = bs.BeautifulSoup(urllib.request.urlopen("https://www.immobilienscout24.de/Suche/S-2/P-"+str(seite)+"/" + type_house).read(),'lxml')
            print("Aktuelle Seite: "+"https://www.immobilienscout24.de/Suche/S-2/P-"+str(seite)+"/"+type_house)
            for paragraph in soup.find_all("a"):

                if r"/expose/" in str(paragraph.get("href")):
                    l.append(paragraph.get("href").split("#")[0])

                l = list(set(l))

            for item in l:

                try:

                    soup = bs.BeautifulSoup(urllib.request.urlopen('https://www.immobilienscout24.de'+item).read(),'lxml')

                    data = pd.DataFrame(json.loads(str(soup.find_all("script")).split("keyValues = ")[1].split("}")[0]+str("}")),index=[str(datetime.now())])

                    data["URL"] = str(item)

                    beschreibung = []

                    for i in soup.find_all("pre"):
                        beschreibung.append(i.text)

                    data["beschreibung"] = str(beschreibung)

                    df = df.append(data)

                except Exception as e: 
                    print(str(datetime.now())+": " + str(e))
                    l = list(filter(lambda x: x != item, l))
                    print("ID " + str(item) + " entfernt.")
            print("Exportiert CSV")
            df.to_csv(str(datetime.now())[:19].replace(":","").replace(".","")+".csv",sep=";",decimal=",",encoding = "utf-8",index_label="timestamp")     

            print("Loop " + str(seite) + " endet.\n")

        except Exception as e: 
            print(str(datetime.now())+": " + str(e))

    print("End of scraping!")

    df = pd.DataFrame()
    n = 0
    for i in os.listdir()[2:-2]:
        n = n + 1
        df = df.append(pd.read_csv(str(i),sep = ";" , decimal = "," , encoding = "utf-8" ))
        print ( "passage" + str ( n ) )
    
    df.to_csv(type_houseouse + '_data.csv')
    
    return df

# %% [markdown]
# # Scraping 4250 pages of wohnung-mieten (rent)
# 1. Make sure that entire directory is empty before running the scraping function every time

# %%
scrape_immobili('wohnung-mieten',4250)

# %% [markdown]
# ### clear the dirctory before running the next function

# %%
scrape_immobili('haus-mieten',230)

# %% [markdown]
# ### clear the dirctory before running the next function
# # Scraping Purchase data

# %%
scrape_immobili('wohnung-kaufen',1650)
# Out:
# Loop 1 startet.
# 2021-05-13 12:10:48.984904: HTTP Error 405:
# Loop 2 startet.
# 2021-05-13 12:10:49.525482: HTTP Error 405:
# Loop 3 startet.
# 2021-05-13 12:10:50.061245: HTTP Error 405:
# Loop 4 startet.
# 2021-05-13 12:10:50.560932: HTTP Error 405:
# Loop 5 startet.
# 2021-05-13 12:10:51.020759: HTTP Error 405:
# Loop 6 startet.
# 2021-05-13 12:10:51.505853: HTTP Error 405:
# Loop 7 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-7/wohnung-kaufen
# 2021-05-13 12:10:53.065284: HTTP Error 405:
# ID /expose/128065941 entfernt.
# 2021-05-13 12:10:53.508503: HTTP Error 405:
# ID /expose/128065570 entfernt.
# 2021-05-13 12:10:54.027716: HTTP Error 405:
# ID /expose/128065562 entfernt.
# 2021-05-13 12:10:54.489409: HTTP Error 405:
# ID /expose/128065935 entfernt.
# 2021-05-13 12:10:56.010829: HTTP Error 405:
# ID /expose/128065852 entfernt.
# C:\Users\PIKU\Anaconda3\lib\site-packages\pandas\core\frame.py:7123: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# 2021-05-13 12:10:57.383310: HTTP Error 405:
# ID /expose/128066234 entfernt.
# 2021-05-13 12:10:57.883770: HTTP Error 405:
# ID /expose/128065684 entfernt.
# 2021-05-13 12:10:58.429554: HTTP Error 405:
# ID /expose/128065337 entfernt.
# 2021-05-13 12:10:58.928277: HTTP Error 405:
# ID /expose/128066010 entfernt.
# 2021-05-13 12:11:00.174316: HTTP Error 405:
# ID /expose/128065326 entfernt.
# 2021-05-13 12:11:00.563879: HTTP Error 405:
# ID /expose/128033611 entfernt.
# 2021-05-13 12:11:01.023629: HTTP Error 405:
# ID /expose/128065589 entfernt.
# 2021-05-13 12:11:01.412314: HTTP Error 405:
# ID /expose/128065727 entfernt.
# 2021-05-13 12:11:01.914117: HTTP Error 405:
# ID /expose/128029743 entfernt.
# 2021-05-13 12:11:05.023405: HTTP Error 405:
# ID /expose/128065894 entfernt.
# Exportiert CSV
# Loop 7 endet.
#
# Loop 8 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-8/wohnung-kaufen
# 2021-05-13 12:11:06.713816: HTTP Error 405:
# ID /expose/128065350 entfernt.
# 2021-05-13 12:11:07.239351: HTTP Error 405:
# ID /expose/128065333 entfernt.
# 2021-05-13 12:11:08.568063: HTTP Error 405:
# ID /expose/128065344 entfernt.
# 2021-05-13 12:11:09.083591: HTTP Error 405:
# ID /expose/128065418 entfernt.
# 2021-05-13 12:11:09.552031: HTTP Error 405:
# ID /expose/128065085 entfernt.
# 2021-05-13 12:11:09.972763: HTTP Error 405:
# ID /expose/128065266 entfernt.
# 2021-05-13 12:11:10.487744: HTTP Error 405:
# ID /expose/128065545 entfernt.
# 2021-05-13 12:11:10.984901: HTTP Error 405:
# ID /expose/128065225 entfernt.
# 2021-05-13 12:11:11.463488: HTTP Error 405:
# ID /expose/124882797 entfernt.
# 2021-05-13 12:11:11.935604: HTTP Error 405:
# ID /expose/128065140 entfernt.
# 2021-05-13 12:11:13.081360: HTTP Error 405:
# ID /expose/128064929 entfernt.
# 2021-05-13 12:11:13.581145: HTTP Error 405:
# ID /expose/128065260 entfernt.
# 2021-05-13 12:11:14.048870: HTTP Error 405:
# ID /expose/128065561 entfernt.
# 2021-05-13 12:11:14.549530: HTTP Error 405:
# ID /expose/128065263 entfernt.
# 2021-05-13 12:11:15.044293: HTTP Error 405:
# ID /expose/128065504 entfernt.
# 2021-05-13 12:11:15.563191: HTTP Error 405:
# ID /expose/128065287 entfernt.
# 2021-05-13 12:11:16.108595: HTTP Error 405:
# ID /expose/128065409 entfernt.
# Exportiert CSV
# Loop 8 endet.
#
# Loop 9 startet.
# 2021-05-13 12:11:17.609979: HTTP Error 405:
# Loop 10 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-10/wohnung-kaufen
# 2021-05-13 12:11:19.141157: HTTP Error 405:
# ID /expose/128064446 entfernt.
# 2021-05-13 12:11:19.639813: HTTP Error 405:
# ID /expose/128064283 entfernt.
# 2021-05-13 12:11:20.053722: HTTP Error 405:
# ID /expose/128057606 entfernt.
# 2021-05-13 12:11:22.390643: HTTP Error 405:
# ID /expose/128064360 entfernt.
# 2021-05-13 12:11:22.857001: HTTP Error 405:
# ID /expose/128064216 entfernt.
# 2021-05-13 12:11:23.279393: HTTP Error 405:
# ID /expose/128064337 entfernt.
# 2021-05-13 12:11:24.574659: HTTP Error 405:
# ID /expose/128064157 entfernt.
# 2021-05-13 12:11:26.059908: HTTP Error 405:
# ID /expose/128064508 entfernt.
# 2021-05-13 12:11:26.544447: HTTP Error 405:
# ID /expose/127080699 entfernt.
# 2021-05-13 12:11:27.054464: HTTP Error 405:
# ID /expose/128064335 entfernt.
# 2021-05-13 12:11:28.310768: HTTP Error 405:
# ID /expose/128064476 entfernt.
# 2021-05-13 12:11:28.816411: HTTP Error 405:
# ID /expose/128064175 entfernt.
# 2021-05-13 12:11:29.252647: HTTP Error 405:
# ID /expose/128064315 entfernt.
# 2021-05-13 12:11:29.694619: HTTP Error 405:
# ID /expose/128064383 entfernt.
# Exportiert CSV
# Loop 10 endet.
#
# Loop 11 startet.
# 2021-05-13 12:11:31.002724: HTTP Error 405:
# Loop 12 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-12/wohnung-kaufen
# 2021-05-13 12:11:32.435659: HTTP Error 405:
# ID /expose/126457761 entfernt.
# 2021-05-13 12:11:33.708430: HTTP Error 405:
# ID /expose/128063268 entfernt.
# 2021-05-13 12:11:35.023540: HTTP Error 405:
# ID /expose/128063396 entfernt.
# 2021-05-13 12:11:35.528956: HTTP Error 405:
# ID /expose/128062704 entfernt.
# 2021-05-13 12:11:36.685341: HTTP Error 405:
# ID /expose/128062972 entfernt.
# 2021-05-13 12:11:38.090331: HTTP Error 405:
# ID /expose/128063011 entfernt.
# 2021-05-13 12:11:38.607213: HTTP Error 405:
# ID /expose/126561788 entfernt.
# 2021-05-13 12:11:40.687411: HTTP Error 405:
# ID /expose/128062961 entfernt.
# 2021-05-13 12:11:41.935107: HTTP Error 405:
# ID /expose/128063525 entfernt.
# 2021-05-13 12:11:43.198550: HTTP Error 405:
# ID /expose/128063314 entfernt.
# 2021-05-13 12:11:43.715467: HTTP Error 405:
# ID /expose/128063480 entfernt.
# 2021-05-13 12:11:44.192437: HTTP Error 405:
# ID /expose/128063551 entfernt.
# 2021-05-13 12:11:44.699437: HTTP Error 405:
# ID /expose/126909387 entfernt.
# Exportiert CSV
# Loop 12 endet.
#
# Loop 13 startet.
# 2021-05-13 12:11:45.167518: HTTP Error 405:
# Loop 14 startet.
# 2021-05-13 12:11:45.666749: HTTP Error 405:
# Loop 15 startet.
# 2021-05-13 12:11:46.103734: HTTP Error 405:
# Loop 16 startet.
# 2021-05-13 12:11:46.542602: HTTP Error 405:
# Loop 17 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-17/wohnung-kaufen
# 2021-05-13 12:11:49.132135: HTTP Error 405:
# ID /expose/128061482 entfernt.
# 2021-05-13 12:11:50.447559: HTTP Error 405:
# ID /expose/127823788 entfernt.
# 2021-05-13 12:11:50.905983: HTTP Error 405:
# ID /expose/128058272 entfernt.
# 2021-05-13 12:11:54.753136: HTTP Error 405:
# ID /expose/128061145 entfernt.
# 2021-05-13 12:11:55.186977: HTTP Error 405:
# ID /expose/128061155 entfernt.
# 2021-05-13 12:11:56.415490: HTTP Error 405:
# ID /expose/128061184 entfernt.
# 2021-05-13 12:11:56.846741: HTTP Error 405:
# ID /expose/128061014 entfernt.
# 2021-05-13 12:11:57.306842: HTTP Error 405:
# ID /expose/128061497 entfernt.
# 2021-05-13 12:11:58.648664: HTTP Error 405:
# ID /expose/128061478 entfernt.
# 2021-05-13 12:12:00.676772: HTTP Error 405:
# ID /expose/128061493 entfernt.
# 2021-05-13 12:12:01.149178: HTTP Error 405:
# ID /expose/128056773 entfernt.
# 2021-05-13 12:12:04.157640: HTTP Error 405:
# ID /expose/128061398 entfernt.
# Exportiert CSV
# Loop 17 endet.
#
# Loop 18 startet.
# 2021-05-13 12:12:04.631933: HTTP Error 405:
# Loop 19 startet.
# 2021-05-13 12:12:05.094549: HTTP Error 405:
# Loop 20 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-20/wohnung-kaufen
# 2021-05-13 12:12:06.698978: HTTP Error 405:
# ID /expose/128060365 entfernt.
# 2021-05-13 12:12:07.207681: HTTP Error 405:
# ID /expose/128060486 entfernt.
# 2021-05-13 12:12:08.602811: HTTP Error 405:
# ID /expose/127996995 entfernt.
# 2021-05-13 12:12:10.710163: HTTP Error 405:
# ID /expose/128060309 entfernt.
# 2021-05-13 12:12:11.182615: HTTP Error 405:
# ID /expose/128058992 entfernt.
# 2021-05-13 12:12:12.458236: HTTP Error 405:
# ID /expose/127816230 entfernt.
# 2021-05-13 12:12:12.892024: HTTP Error 405:
# ID /expose/128060409 entfernt.
# 2021-05-13 12:12:13.400415: HTTP Error 405:
# ID /expose/128060509 entfernt.
# 2021-05-13 12:12:13.886327: HTTP Error 405:
# ID /expose/128059949 entfernt.
# 2021-05-13 12:12:14.386203: HTTP Error 405:
# ID /expose/128060355 entfernt.
# 2021-05-13 12:12:16.403077: HTTP Error 405:
# ID /expose/127841911 entfernt.
# 2021-05-13 12:12:16.888610: HTTP Error 405:
# ID /expose/128060489 entfernt.
# 2021-05-13 12:12:17.395413: HTTP Error 405:
# ID /expose/128060014 entfernt.
# 2021-05-13 12:12:17.916669: HTTP Error 405:
# ID /expose/128057379 entfernt.
# 2021-05-13 12:12:19.149126: HTTP Error 405:
# ID /expose/128060481 entfernt.
# 2021-05-13 12:12:19.585813: HTTP Error 405:
# ID /expose/128060021 entfernt.
# Exportiert CSV
# Loop 20 endet.
#
# Loop 21 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-21/wohnung-kaufen
# 2021-05-13 12:12:20.915201: HTTP Error 405:
# ID /expose/128059336 entfernt.
# 2021-05-13 12:12:21.380953: HTTP Error 405:
# ID /expose/128059457 entfernt.
# 2021-05-13 12:12:21.824687: HTTP Error 405:
# ID /expose/128059353 entfernt.
# 2021-05-13 12:12:24.691856: HTTP Error 405:
# ID /expose/128059231 entfernt.
# 2021-05-13 12:12:25.126765: HTTP Error 405:
# ID /expose/128058098 entfernt.
# 2021-05-13 12:12:26.463993: HTTP Error 405:
# ID /expose/128059229 entfernt.
# 2021-05-13 12:12:26.963955: HTTP Error 405:
# ID /expose/128059376 entfernt.
# 2021-05-13 12:12:27.476718: HTTP Error 405:
# ID /expose/128059345 entfernt.
# 2021-05-13 12:12:29.595737: HTTP Error 405:
# ID /expose/128059408 entfernt.
# 2021-05-13 12:12:30.030013: HTTP Error 405:
# ID /expose/128059233 entfernt.
# 2021-05-13 12:12:32.185702: HTTP Error 405:
# ID /expose/127971588 entfernt.
# 2021-05-13 12:12:32.819995: HTTP Error 405:
# ID /expose/128059637 entfernt.
# Exportiert CSV
# Loop 21 endet.
#
# Loop 22 startet.
# 2021-05-13 12:12:33.333597: HTTP Error 405:
# Loop 23 startet.
# 2021-05-13 12:12:33.833042: HTTP Error 405:
# Loop 24 startet.
# 2021-05-13 12:12:34.347605: HTTP Error 405:
# Loop 25 startet.
# 2021-05-13 12:12:34.836124: HTTP Error 405:
# Loop 26 startet.
# 2021-05-13 12:12:35.237771: HTTP Error 405:
# Loop 27 startet.
# 2021-05-13 12:12:35.678364: HTTP Error 405:
# Loop 28 startet.
# 2021-05-13 12:12:36.190292: HTTP Error 405:
# Loop 29 startet.
# 2021-05-13 12:12:36.659735: HTTP Error 405:
# Loop 30 startet.
# 2021-05-13 12:12:37.143914: HTTP Error 405:
# Loop 31 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-31/wohnung-kaufen
# 2021-05-13 12:12:39.239331: HTTP Error 405:
# ID /expose/123689805 entfernt.
# 2021-05-13 12:12:39.660795: HTTP Error 405:
# ID /expose/128055576 entfernt.
# 2021-05-13 12:12:41.911556: HTTP Error 405:
# ID /expose/128055644 entfernt.
# 2021-05-13 12:12:42.392076: HTTP Error 405:
# ID /expose/128055811 entfernt.
# 2021-05-13 12:12:42.907738: HTTP Error 405:
# ID /expose/128054543 entfernt.
# 2021-05-13 12:12:43.376701: HTTP Error 405:
# ID /expose/127847026 entfernt.
# 2021-05-13 12:12:44.644179: HTTP Error 405:
# ID /expose/128055779 entfernt.
# 2021-05-13 12:12:45.142071: HTTP Error 405:
# ID /expose/128055764 entfernt.
# 2021-05-13 12:12:47.196016: HTTP Error 405:
# ID /expose/128055789 entfernt.
# 2021-05-13 12:12:47.611043: HTTP Error 405:
# ID /expose/128055667 entfernt.
# 2021-05-13 12:12:48.159816: HTTP Error 405:
# ID /expose/128054735 entfernt.
# 2021-05-13 12:12:48.684303: HTTP Error 405:
# ID /expose/128054575 entfernt.
# 2021-05-13 12:12:49.141292: HTTP Error 405:
# ID /expose/128055647 entfernt.
# 2021-05-13 12:12:49.640874: HTTP Error 405:
# ID /expose/128055622 entfernt.
# 2021-05-13 12:12:50.126808: HTTP Error 405:
# ID /expose/127974196 entfernt.
# 2021-05-13 12:12:51.393311: HTTP Error 405:
# ID /expose/127845843 entfernt.
# Exportiert CSV
# Loop 31 endet.
#
# Loop 32 startet.
# 2021-05-13 12:12:51.858994: HTTP Error 405:
# Loop 33 startet.
# 2021-05-13 12:12:52.366971: HTTP Error 405:
# Loop 34 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-34/wohnung-kaufen
# 2021-05-13 12:12:53.765123: HTTP Error 405:
# ID /expose/128054576 entfernt.
# 2021-05-13 12:12:54.265348: HTTP Error 405:
# ID /expose/126697383 entfernt.
# 2021-05-13 12:12:54.780082: HTTP Error 405:
# ID /expose/128053386 entfernt.
# 2021-05-13 12:12:55.234168: HTTP Error 405:
# ID /expose/128054502 entfernt.
# 2021-05-13 12:12:55.765355: HTTP Error 405:
# ID /expose/127650453 entfernt.
# 2021-05-13 12:12:58.926277: HTTP Error 405:
# ID /expose/128054689 entfernt.
# 2021-05-13 12:13:00.168162: HTTP Error 405:
# ID /expose/128054490 entfernt.
# 2021-05-13 12:13:00.653273: HTTP Error 405:
# ID /expose/128054445 entfernt.
# 2021-05-13 12:13:01.137550: HTTP Error 405:
# ID /expose/128054399 entfernt.
# 2021-05-13 12:13:01.635905: HTTP Error 405:
# ID /expose/128054704 entfernt.
# 2021-05-13 12:13:02.155761: HTTP Error 405:
# ID /expose/128054797 entfernt.
# 2021-05-13 12:13:02.650109: HTTP Error 405:
# ID /expose/128053716 entfernt.
# 2021-05-13 12:13:03.135200: HTTP Error 405:
# ID /expose/128054639 entfernt.
# 2021-05-13 12:13:04.378368: HTTP Error 405:
# ID /expose/128054569 entfernt.
# 2021-05-13 12:13:04.887036: HTTP Error 405:
# ID /expose/128054492 entfernt.
# Exportiert CSV
# Loop 34 endet.
#
# Loop 35 startet.
# 2021-05-13 12:13:05.391900: HTTP Error 405:
# Loop 36 startet.
# 2021-05-13 12:13:05.968262: HTTP Error 405:
# Loop 37 startet.
# 2021-05-13 12:13:06.445922: HTTP Error 405:
# Loop 38 startet.
# 2021-05-13 12:13:06.963130: HTTP Error 405:
# Loop 39 startet.
# 2021-05-13 12:13:07.398162: HTTP Error 405:
# Loop 40 startet.
# 2021-05-13 12:13:07.898037: HTTP Error 405:
# Loop 41 startet.
# 2021-05-13 12:13:08.368898: HTTP Error 405:
# Loop 42 startet.
# 2021-05-13 12:13:08.836095: HTTP Error 405:
# Loop 43 startet.
# 2021-05-13 12:13:09.337011: HTTP Error 405:
# Loop 44 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-44/wohnung-kaufen
# 2021-05-13 12:13:10.740309: HTTP Error 405:
# ID /expose/128047151 entfernt.
# 2021-05-13 12:13:12.077964: HTTP Error 405:
# ID /expose/128047141 entfernt.
# 2021-05-13 12:13:12.574570: HTTP Error 405:
# ID /expose/128047144 entfernt.
# 2021-05-13 12:13:13.067993: HTTP Error 405:
# ID /expose/128047139 entfernt.
# 2021-05-13 12:13:14.460146: HTTP Error 405:
# ID /expose/128047138 entfernt.
# 2021-05-13 12:13:14.942236: HTTP Error 405:
# ID /expose/128047150 entfernt.
# 2021-05-13 12:13:15.459551: HTTP Error 405:
# ID /expose/128047147 entfernt.
# 2021-05-13 12:13:15.972466: HTTP Error 405:
# ID /expose/128047136 entfernt.
# 2021-05-13 12:13:16.509468: HTTP Error 405:
# ID /expose/128047143 entfernt.
# 2021-05-13 12:13:16.972353: HTTP Error 405:
# ID /expose/128047140 entfernt.
# 2021-05-13 12:13:17.472779: HTTP Error 405:
# ID /expose/128047154 entfernt.
# 2021-05-13 12:13:18.770312: HTTP Error 405:
# ID /expose/128047145 entfernt.
# 2021-05-13 12:13:19.237270: HTTP Error 405:
# ID /expose/128047146 entfernt.
# 2021-05-13 12:13:20.497837: HTTP Error 405:
# ID /expose/128047153 entfernt.
# Exportiert CSV
# Loop 44 endet.
#
# Loop 45 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-45/wohnung-kaufen
# 2021-05-13 12:13:23.611574: HTTP Error 405:
# ID /expose/128045755 entfernt.
# 2021-05-13 12:13:24.067459: HTTP Error 405:
# ID /expose/128047126 entfernt.
# 2021-05-13 12:13:24.540662: HTTP Error 405:
# ID /expose/127958602 entfernt.
# 2021-05-13 12:13:25.813888: HTTP Error 405:
# ID /expose/128046633 entfernt.
# 2021-05-13 12:13:27.080221: HTTP Error 405:
# ID /expose/128047037 entfernt.
# 2021-05-13 12:13:27.580520: HTTP Error 405:
# ID /expose/113615589 entfernt.
# 2021-05-13 12:13:28.094937: HTTP Error 405:
# ID /expose/128047132 entfernt.
# 2021-05-13 12:13:28.531684: HTTP Error 405:
# ID /expose/128046950 entfernt.
# 2021-05-13 12:13:29.987728: HTTP Error 405:
# ID /expose/128047135 entfernt.
# 2021-05-13 12:13:30.480805: HTTP Error 405:
# ID /expose/128042026 entfernt.
# 2021-05-13 12:13:30.971132: HTTP Error 405:
# ID /expose/127701753 entfernt.
# 2021-05-13 12:13:31.470057: HTTP Error 405:
# ID /expose/128047134 entfernt.
# 2021-05-13 12:13:32.821439: HTTP Error 405:
# ID /expose/128047133 entfernt.
# 2021-05-13 12:13:33.346654: HTTP Error 405:
# ID /expose/128046866 entfernt.
# 2021-05-13 12:13:33.831853: HTTP Error 405:
# ID /expose/128047112 entfernt.
# 2021-05-13 12:13:34.268247: HTTP Error 405:
# ID /expose/128047131 entfernt.
# 2021-05-13 12:13:34.759929: HTTP Error 405:
# ID /expose/128047130 entfernt.
# Exportiert CSV
# Loop 45 endet.
#
# Loop 46 startet.
# 2021-05-13 12:13:35.329040: HTTP Error 405:
# Loop 47 startet.
# 2021-05-13 12:13:35.846928: HTTP Error 405:
# Loop 48 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-48/wohnung-kaufen
# 2021-05-13 12:13:38.227913: HTTP Error 405:
# ID /expose/127940785 entfernt.
# 2021-05-13 12:13:38.741930: HTTP Error 405:
# ID /expose/128043922 entfernt.
# 2021-05-13 12:13:39.246398: HTTP Error 405:
# ID /expose/128044010 entfernt.
# 2021-05-13 12:13:39.741492: HTTP Error 405:
# ID /expose/128043694 entfernt.
# 2021-05-13 12:13:40.233568: HTTP Error 405:
# ID /expose/128044368 entfernt.
# 2021-05-13 12:13:40.728026: HTTP Error 405:
# ID /expose/126951573 entfernt.
# 2021-05-13 12:13:41.215199: HTTP Error 405:
# ID /expose/127100849 entfernt.
# 2021-05-13 12:13:41.710772: HTTP Error 405:
# ID /expose/126885766 entfernt.
# 2021-05-13 12:13:42.162367: HTTP Error 405:
# ID /expose/124853027 entfernt.
# 2021-05-13 12:13:42.655950: HTTP Error 405:
# ID /expose/128044924 entfernt.
# 2021-05-13 12:13:43.105751: HTTP Error 405:
# ID /expose/126815324 entfernt.
# 2021-05-13 12:13:43.639989: HTTP Error 405:
# ID /expose/127100581 entfernt.
# 2021-05-13 12:13:44.167813: HTTP Error 405:
# ID /expose/128044225 entfernt.
# 2021-05-13 12:13:45.465019: HTTP Error 405:
# ID /expose/128020767 entfernt.
# 2021-05-13 12:13:45.909395: HTTP Error 405:
# ID /expose/128044516 entfernt.
# 2021-05-13 12:13:46.373087: HTTP Error 405:
# ID /expose/128044499 entfernt.
# 2021-05-13 12:13:47.827706: HTTP Error 405:
# ID /expose/128044243 entfernt.
# Exportiert CSV
# Loop 48 endet.
#
# Loop 49 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-49/wohnung-kaufen
# 2021-05-13 12:13:51.143576: HTTP Error 405:
# ID /expose/128043772 entfernt.
# 2021-05-13 12:13:51.685255: HTTP Error 405:
# ID /expose/128044063 entfernt.
# 2021-05-13 12:13:52.144344: HTTP Error 405:
# ID /expose/128044002 entfernt.
# 2021-05-13 12:13:53.498293: HTTP Error 405:
# ID /expose/128043858 entfernt.
# 2021-05-13 12:13:55.547412: HTTP Error 405:
# ID /expose/128043700 entfernt.
# 2021-05-13 12:13:56.965793: HTTP Error 405:
# ID /expose/128043453 entfernt.
# 2021-05-13 12:13:58.344501: HTTP Error 405:
# ID /expose/128043783 entfernt.
# 2021-05-13 12:13:58.847151: HTTP Error 405:
# ID /expose/125973559 entfernt.
# 2021-05-13 12:13:59.334215: HTTP Error 405:
# ID /expose/128044041 entfernt.
# 2021-05-13 12:13:59.847034: HTTP Error 405:
# ID /expose/128043940 entfernt.
# 2021-05-13 12:14:04.844980: HTTP Error 405:
# ID /expose/127926065 entfernt.
# Exportiert CSV
# Loop 49 endet.
#
# Loop 50 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-50/wohnung-kaufen
# 2021-05-13 12:14:07.904492: HTTP Error 405:
# ID /expose/128043702 entfernt.
# 2021-05-13 12:14:08.479102: HTTP Error 405:
# ID /expose/81768037 entfernt.
# 2021-05-13 12:14:13.293616: HTTP Error 405:
# ID /expose/127937787 entfernt.
# 2021-05-13 12:14:13.817593: HTTP Error 405:
# ID /expose/128043164 entfernt.
# 2021-05-13 12:14:14.312790: HTTP Error 405:
# ID /expose/127290854 entfernt.
# 2021-05-13 12:14:14.812445: HTTP Error 405:
# ID /expose/128043367 entfernt.
# 2021-05-13 12:14:15.325551: HTTP Error 405:
# ID /expose/128043744 entfernt.
# 2021-05-13 12:14:15.808745: HTTP Error 405:
# ID /expose/128038809 entfernt.
# 2021-05-13 12:14:17.129034: HTTP Error 405:
# ID /expose/128043492 entfernt.
# 2021-05-13 12:14:17.589728: HTTP Error 405:
# ID /expose/128043493 entfernt.
# 2021-05-13 12:14:18.012720: HTTP Error 405:
# ID /expose/128043471 entfernt.
# 2021-05-13 12:14:18.541413: HTTP Error 405:
# ID /expose/128043425 entfernt.
# 2021-05-13 12:14:19.989325: HTTP Error 405:
# ID /expose/128043519 entfernt.
# Exportiert CSV
# Loop 50 endet.
#
# Loop 51 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-51/wohnung-kaufen
# 2021-05-13 12:14:22.384350: HTTP Error 405:
# ID /expose/128043239 entfernt.
# 2021-05-13 12:14:22.861213: HTTP Error 405:
# ID /expose/127739510 entfernt.
# 2021-05-13 12:14:24.251174: HTTP Error 405:
# ID /expose/128043117 entfernt.
# 2021-05-13 12:14:24.765501: HTTP Error 405:
# ID /expose/128043192 entfernt.
# 2021-05-13 12:14:26.825618: HTTP Error 405:
# ID /expose/128042968 entfernt.
# 2021-05-13 12:14:29.004606: HTTP Error 405:
# ID /expose/127737934 entfernt.
# 2021-05-13 12:14:29.502189: HTTP Error 405:
# ID /expose/128043033 entfernt.
# 2021-05-13 12:14:30.010554: HTTP Error 405:
# ID /expose/128042456 entfernt.
# 2021-05-13 12:14:30.452528: HTTP Error 405:
# ID /expose/128043221 entfernt.
# 2021-05-13 12:14:30.932401: HTTP Error 405:
# ID /expose/128043063 entfernt.
# 2021-05-13 12:14:32.188773: HTTP Error 405:
# ID /expose/128030522 entfernt.
# 2021-05-13 12:14:32.685196: HTTP Error 405:
# ID /expose/128043180 entfernt.
# 2021-05-13 12:14:33.167261: HTTP Error 405:
# ID /expose/128043227 entfernt.
# Exportiert CSV
# Loop 51 endet.
#
# Loop 52 startet.
# 2021-05-13 12:14:34.444276: HTTP Error 405:
# Loop 53 startet.
# 2021-05-13 12:14:34.959943: HTTP Error 405:
# Loop 54 startet.
# 2021-05-13 12:14:35.402884: HTTP Error 405:
# Loop 55 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-55/wohnung-kaufen
# 2021-05-13 12:14:39.341453: HTTP Error 405:
# ID /expose/128041364 entfernt.
# 2021-05-13 12:14:39.854127: HTTP Error 405:
# ID /expose/128041837 entfernt.
# 2021-05-13 12:14:40.288116: HTTP Error 405:
# ID /expose/128041444 entfernt.
# 2021-05-13 12:14:40.769131: HTTP Error 405:
# ID /expose/128041344 entfernt.
# 2021-05-13 12:14:41.978242: HTTP Error 405:
# ID /expose/128041307 entfernt.
# 2021-05-13 12:14:44.183599: HTTP Error 405:
# ID /expose/128041554 entfernt.
# 2021-05-13 12:14:44.631024: HTTP Error 405:
# ID /expose/128041351 entfernt.
# 2021-05-13 12:14:45.082227: HTTP Error 405:
# ID /expose/128041012 entfernt.
# 2021-05-13 12:14:45.602514: HTTP Error 405:
# ID /expose/128041501 entfernt.
# 2021-05-13 12:14:46.108552: HTTP Error 405:
# ID /expose/128041600 entfernt.
# 2021-05-13 12:14:46.629137: HTTP Error 405:
# ID /expose/128041101 entfernt.
# 2021-05-13 12:14:48.021783: HTTP Error 405:
# ID /expose/128041322 entfernt.
# Exportiert CSV
# Loop 55 endet.
#
# Loop 56 startet.
# 2021-05-13 12:14:49.386764: HTTP Error 405:
# Loop 57 startet.
# 2021-05-13 12:14:49.877358: HTTP Error 405:
# Loop 58 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-58/wohnung-kaufen
# 2021-05-13 12:14:52.039831: HTTP Error 405:
# ID /expose/123286391 entfernt.
# 2021-05-13 12:14:52.494562: HTTP Error 405:
# ID /expose/128040053 entfernt.
# 2021-05-13 12:14:53.874093: HTTP Error 405:
# ID /expose/123345452 entfernt.
# 2021-05-13 12:14:56.090968: HTTP Error 405:
# ID /expose/128039816 entfernt.
# 2021-05-13 12:14:58.279447: HTTP Error 405:
# ID /expose/128040123 entfernt.
# 2021-05-13 12:14:58.816522: HTTP Error 405:
# ID /expose/128039964 entfernt.
# 2021-05-13 12:14:59.297121: HTTP Error 405:
# ID /expose/128037587 entfernt.
# 2021-05-13 12:15:03.017726: HTTP Error 405:
# ID /expose/128040126 entfernt.
# 2021-05-13 12:15:05.216268: HTTP Error 405:
# ID /expose/128039140 entfernt.
# Exportiert CSV
# Loop 58 endet.
#
# Loop 59 startet.
# 2021-05-13 12:15:05.748952: HTTP Error 405:
# Loop 60 startet.
# 2021-05-13 12:15:06.243517: HTTP Error 405:
# Loop 61 startet.
# 2021-05-13 12:15:06.723748: HTTP Error 405:
# Loop 62 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-62/wohnung-kaufen
# 2021-05-13 12:15:08.382524: HTTP Error 405:
# ID /expose/127999166 entfernt.
# 2021-05-13 12:15:08.888592: HTTP Error 405:
# ID /expose/127998895 entfernt.
# 2021-05-13 12:15:10.170785: HTTP Error 405:
# ID /expose/128038000 entfernt.
# 2021-05-13 12:15:12.274039: HTTP Error 405:
# ID /expose/128037279 entfernt.
# 2021-05-13 12:15:13.587094: HTTP Error 405:
# ID /expose/128037729 entfernt.
# 2021-05-13 12:15:14.954528: HTTP Error 405:
# ID /expose/128037609 entfernt.
# 2021-05-13 12:15:17.579614: HTTP Error 405:
# ID /expose/128037816 entfernt.
# 2021-05-13 12:15:19.687973: HTTP Error 405:
# ID /expose/128037552 entfernt.
# 2021-05-13 12:15:21.837580: HTTP Error 405:
# ID /expose/128036371 entfernt.
# 2021-05-13 12:15:22.339254: HTTP Error 405:
# ID /expose/122455879 entfernt.
# 2021-05-13 12:15:22.830779: HTTP Error 405:
# ID /expose/128036663 entfernt.
# Exportiert CSV
# Loop 62 endet.
#
# Loop 63 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-63/wohnung-kaufen
# 2021-05-13 12:15:24.235799: HTTP Error 405:
# ID /expose/128036866 entfernt.
# 2021-05-13 12:15:24.655731: HTTP Error 405:
# ID /expose/128036885 entfernt.
# 2021-05-13 12:15:25.116633: HTTP Error 405:
# ID /expose/122199530 entfernt.
# 2021-05-13 12:15:28.036567: HTTP Error 405:
# ID /expose/128037371 entfernt.
# 2021-05-13 12:15:29.215771: HTTP Error 405:
# ID /expose/128036922 entfernt.
# 2021-05-13 12:15:29.710250: HTTP Error 405:
# ID /expose/128037449 entfernt.
# 2021-05-13 12:15:30.220473: HTTP Error 405:
# ID /expose/128037109 entfernt.
# 2021-05-13 12:15:31.538675: HTTP Error 405:
# ID /expose/128019493 entfernt.
# 2021-05-13 12:15:32.034153: HTTP Error 405:
# ID /expose/128037287 entfernt.
# 2021-05-13 12:15:34.151227: HTTP Error 405:
# ID /expose/128037230 entfernt.
# 2021-05-13 12:15:37.848751: HTTP Error 405:
# ID /expose/128037390 entfernt.
# Exportiert CSV
# Loop 63 endet.
#
# Loop 64 startet.
# 2021-05-13 12:15:38.333012: HTTP Error 405:
# Loop 65 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-65/wohnung-kaufen
# 2021-05-13 12:15:39.777340: HTTP Error 405:
# ID /expose/128036383 entfernt.
# 2021-05-13 12:15:40.214584: HTTP Error 405:
# ID /expose/128036160 entfernt.
# 2021-05-13 12:15:40.702266: HTTP Error 405:
# ID /expose/128036230 entfernt.
# 2021-05-13 12:15:41.216994: HTTP Error 405:
# ID /expose/128036498 entfernt.
# 2021-05-13 12:15:45.187101: HTTP Error 405:
# ID /expose/128036486 entfernt.
# 2021-05-13 12:15:45.654381: HTTP Error 405:
# ID /expose/128036382 entfernt.
# 2021-05-13 12:15:46.132647: HTTP Error 405:
# ID /expose/128036481 entfernt.
# 2021-05-13 12:15:46.543576: HTTP Error 405:
# ID /expose/128036367 entfernt.
# 2021-05-13 12:15:47.042787: HTTP Error 405:
# ID /expose/128036454 entfernt.
# 2021-05-13 12:15:47.504424: HTTP Error 405:
# ID /expose/128036007 entfernt.
# 2021-05-13 12:15:47.953221: HTTP Error 405:
# ID /expose/128035577 entfernt.
# 2021-05-13 12:15:48.427025: HTTP Error 405:
# ID /expose/128036106 entfernt.
# 2021-05-13 12:15:48.820331: HTTP Error 405:
# ID /expose/128036348 entfernt.
# 2021-05-13 12:15:49.242079: HTTP Error 405:
# ID /expose/128036496 entfernt.
# 2021-05-13 12:15:49.694501: HTTP Error 405:
# ID /expose/128036102 entfernt.
# 2021-05-13 12:15:50.178792: HTTP Error 405:
# ID /expose/128036208 entfernt.
# 2021-05-13 12:15:50.642013: HTTP Error 405:
# ID /expose/127935494 entfernt.
# 2021-05-13 12:15:51.110134: HTTP Error 405:
# ID /expose/128036442 entfernt.
# Exportiert CSV
# Loop 65 endet.
#
# Loop 66 startet.
# 2021-05-13 12:15:51.625481: HTTP Error 405:
# Loop 67 startet.
# 2021-05-13 12:15:52.125368: HTTP Error 405:
# Loop 68 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-68/wohnung-kaufen
# 2021-05-13 12:15:54.444361: HTTP Error 405:
# ID /expose/128034888 entfernt.
# 2021-05-13 12:15:54.956378: HTTP Error 405:
# ID /expose/127990068 entfernt.
# 2021-05-13 12:15:58.721342: HTTP Error 405:
# ID /expose/128034594 entfernt.
# 2021-05-13 12:16:02.058279: HTTP Error 405:
# ID /expose/128035125 entfernt.
# 2021-05-13 12:16:02.549102: HTTP Error 405:
# ID /expose/128034666 entfernt.
# 2021-05-13 12:16:03.017607: HTTP Error 405:
# ID /expose/128034883 entfernt.
# 2021-05-13 12:16:06.233253: HTTP Error 405:
# ID /expose/128035049 entfernt.
# Exportiert CSV
# Loop 68 endet.
#
# Loop 69 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-69/wohnung-kaufen
# 2021-05-13 12:16:09.570353: HTTP Error 405:
# ID /expose/128034601 entfernt.
# 2021-05-13 12:16:10.912667: HTTP Error 405:
# ID /expose/128033769 entfernt.
# 2021-05-13 12:16:11.332544: HTTP Error 405:
# ID /expose/128034528 entfernt.
# 2021-05-13 12:16:14.914438: HTTP Error 405:
# ID /expose/128034188 entfernt.
# 2021-05-13 12:16:15.320057: HTTP Error 405:
# ID /expose/125646301 entfernt.
# 2021-05-13 12:16:19.412617: HTTP Error 405:
# ID /expose/128034748 entfernt.
# 2021-05-13 12:16:19.912513: HTTP Error 405:
# ID /expose/128034411 entfernt.
# 2021-05-13 12:16:20.414170: HTTP Error 405:
# ID /expose/128034591 entfernt.
# 2021-05-13 12:16:20.896932: HTTP Error 405:
# ID /expose/128034665 entfernt.
# 2021-05-13 12:16:21.378640: HTTP Error 405:
# ID /expose/128034365 entfernt.
# 2021-05-13 12:16:22.691826: HTTP Error 405:
# ID /expose/128034274 entfernt.
# 2021-05-13 12:16:23.173888: HTTP Error 405:
# ID /expose/128034635 entfernt.
# Exportiert CSV
# Loop 69 endet.
#
# Loop 70 startet.
# 2021-05-13 12:16:23.600747: HTTP Error 405:
# Loop 71 startet.
# 2021-05-13 12:16:24.024302: HTTP Error 405:
# Loop 72 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-72/wohnung-kaufen
# 2021-05-13 12:16:25.589292: HTTP Error 405:
# ID /expose/128030471 entfernt.
# 2021-05-13 12:16:28.078059: HTTP Error 405:
# ID /expose/128030819 entfernt.
# 2021-05-13 12:16:28.491735: HTTP Error 405:
# ID /expose/128030507 entfernt.
# 2021-05-13 12:16:29.842570: HTTP Error 405:
# ID /expose/128032606 entfernt.
# 2021-05-13 12:16:30.335186: HTTP Error 405:
# ID /expose/128027840 entfernt.
# 2021-05-13 12:16:30.781049: HTTP Error 405:
# ID /expose/128030499 entfernt.
# 2021-05-13 12:16:32.150650: HTTP Error 405:
# ID /expose/128031159 entfernt.
# 2021-05-13 12:16:33.483532: HTTP Error 405:
# ID /expose/127879021 entfernt.
# 2021-05-13 12:16:33.972462: HTTP Error 405:
# ID /expose/128031110 entfernt.
# 2021-05-13 12:16:34.539645: HTTP Error 405:
# ID /expose/128030504 entfernt.
# 2021-05-13 12:16:39.092580: HTTP Error 405:
# ID /expose/128008997 entfernt.
# 2021-05-13 12:16:39.635273: HTTP Error 405:
# ID /expose/128030913 entfernt.
# 2021-05-13 12:16:40.316877: HTTP Error 405:
# ID /expose/128030513 entfernt.
# 2021-05-13 12:16:41.115139: HTTP Error 405:
# ID /expose/128031626 entfernt.
# 2021-05-13 12:16:41.800422: HTTP Error 405:
# ID /expose/128030494 entfernt.
# Exportiert CSV
# Loop 72 endet.
#
# Loop 73 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-73/wohnung-kaufen
# 2021-05-13 12:16:44.361007: HTTP Error 405:
# ID /expose/128029955 entfernt.
# 2021-05-13 12:16:46.761898: HTTP Error 405:
# ID /expose/128030364 entfernt.
# 2021-05-13 12:16:49.709857: HTTP Error 405:
# ID /expose/127985627 entfernt.
# 2021-05-13 12:16:50.563814: HTTP Error 405:
# ID /expose/128029427 entfernt.
# 2021-05-13 12:16:52.447563: HTTP Error 405:
# ID /expose/128030020 entfernt.
# 2021-05-13 12:16:55.705238: HTTP Error 405:
# ID /expose/126116616 entfernt.
# 2021-05-13 12:16:56.209991: HTTP Error 405:
# ID /expose/128030022 entfernt.
# 2021-05-13 12:16:56.819394: HTTP Error 405:
# ID /expose/128030305 entfernt.
# 2021-05-13 12:16:57.388299: HTTP Error 405:
# ID /expose/128029952 entfernt.
# 2021-05-13 12:16:59.222598: HTTP Error 405:
# ID /expose/128030048 entfernt.
# 2021-05-13 12:17:02.667892: HTTP Error 405:
# ID /expose/128029910 entfernt.
# 2021-05-13 12:17:03.183437: HTTP Error 405:
# ID /expose/127536737 entfernt.
# Exportiert CSV
# Loop 73 endet.
#
# Loop 74 startet.
# 2021-05-13 12:17:03.830707: HTTP Error 405:
# Loop 75 startet.
# 2021-05-13 12:17:04.563039: HTTP Error 405:
# Loop 76 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-76/wohnung-kaufen
# 2021-05-13 12:17:06.945516: HTTP Error 405:
# ID /expose/128029136 entfernt.
# 2021-05-13 12:17:07.621735: HTTP Error 405:
# ID /expose/128028909 entfernt.
# 2021-05-13 12:17:08.194089: HTTP Error 405:
# ID /expose/128028818 entfernt.
# 2021-05-13 12:17:08.775534: HTTP Error 405:
# ID /expose/128029352 entfernt.
# 2021-05-13 12:17:10.501952: HTTP Error 405:
# ID /expose/128029152 entfernt.
# 2021-05-13 12:17:12.435748: HTTP Error 405:
# ID /expose/128028825 entfernt.
# 2021-05-13 12:17:14.390522: HTTP Error 405:
# ID /expose/128029355 entfernt.
# 2021-05-13 12:17:14.829350: HTTP Error 405:
# ID /expose/128029357 entfernt.
# 2021-05-13 12:17:15.240250: HTTP Error 405:
# ID /expose/128029312 entfernt.
# 2021-05-13 12:17:15.677081: HTTP Error 405:
# ID /expose/128029359 entfernt.
# 2021-05-13 12:17:16.161786: HTTP Error 405:
# ID /expose/128029335 entfernt.
# 2021-05-13 12:17:16.789108: HTTP Error 405:
# ID /expose/126978269 entfernt.
# 2021-05-13 12:17:17.197018: HTTP Error 405:
# ID /expose/128029194 entfernt.
# 2021-05-13 12:17:17.663770: HTTP Error 405:
# ID /expose/128029353 entfernt.
# 2021-05-13 12:17:18.119551: HTTP Error 405:
# ID /expose/128028904 entfernt.
# 2021-05-13 12:17:18.566357: HTTP Error 405:
# ID /expose/128029358 entfernt.
# Exportiert CSV
# Loop 76 endet.
#
# Loop 77 startet.
# 2021-05-13 12:17:19.045078: HTTP Error 405:
# Loop 78 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-78/wohnung-kaufen
# 2021-05-13 12:17:20.404444: HTTP Error 405:
# ID /expose/128027611 entfernt.
# 2021-05-13 12:17:20.867205: HTTP Error 405:
# ID /expose/128027630 entfernt.
# 2021-05-13 12:17:23.453292: HTTP Error 405:
# ID /expose/128027633 entfernt.
# 2021-05-13 12:17:23.933009: HTTP Error 405:
# ID /expose/114304687 entfernt.
# 2021-05-13 12:17:25.353212: HTTP Error 405:
# ID /expose/128028015 entfernt.
# 2021-05-13 12:17:25.743169: HTTP Error 405:
# ID /expose/128027923 entfernt.
# 2021-05-13 12:17:27.002802: HTTP Error 405:
# ID /expose/128027743 entfernt.
# 2021-05-13 12:17:27.461576: HTTP Error 405:
# ID /expose/128009222 entfernt.
# 2021-05-13 12:17:27.884445: HTTP Error 405:
# ID /expose/127949942 entfernt.
# 2021-05-13 12:17:29.169273: HTTP Error 405:
# ID /expose/128028298 entfernt.
# 2021-05-13 12:17:29.651983: HTTP Error 405:
# ID /expose/128026521 entfernt.
# 2021-05-13 12:17:30.991442: HTTP Error 405:
# ID /expose/128028280 entfernt.
# 2021-05-13 12:17:31.488730: HTTP Error 405:
# ID /expose/128027930 entfernt.
# Exportiert CSV
# Loop 78 endet.
#
# Loop 79 startet.
# 2021-05-13 12:17:32.266961: HTTP Error 405:
# Loop 80 startet.
# 2021-05-13 12:17:32.762891: HTTP Error 405:
# Loop 81 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-81/wohnung-kaufen
# 2021-05-13 12:17:35.130389: HTTP Error 405:
# ID /expose/128023006 entfernt.
# 2021-05-13 12:17:35.608699: HTTP Error 405:
# ID /expose/126816255 entfernt.
# 2021-05-13 12:17:36.464578: HTTP Error 405:
# ID /expose/128026379 entfernt.
# 2021-05-13 12:17:36.955339: HTTP Error 405:
# ID /expose/128026584 entfernt.
# 2021-05-13 12:17:37.409126: HTTP Error 405:
# ID /expose/128026299 entfernt.
# 2021-05-13 12:17:39.600962: HTTP Error 405:
# ID /expose/128016119 entfernt.
# 2021-05-13 12:17:45.290358: HTTP Error 405:
# ID /expose/128026310 entfernt.
# 2021-05-13 12:17:46.028597: HTTP Error 405:
# ID /expose/128026352 entfernt.
# 2021-05-13 12:17:46.779884: HTTP Error 405:
# ID /expose/128026227 entfernt.
# 2021-05-13 12:17:47.391068: HTTP Error 405:
# ID /expose/127492857 entfernt.
# 2021-05-13 12:17:47.960040: HTTP Error 405:
# ID /expose/127896773 entfernt.
# 2021-05-13 12:17:50.274185: HTTP Error 405:
# ID /expose/128025012 entfernt.
# 2021-05-13 12:17:51.101163: HTTP Error 405:
# ID /expose/125644675 entfernt.
# 2021-05-13 12:17:51.715567: HTTP Error 405:
# ID /expose/126816256 entfernt.
# Exportiert CSV
# Loop 81 endet.
#
# Loop 82 startet.
# 2021-05-13 12:17:53.280879: HTTP Error 405:
# Loop 83 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-83/wohnung-kaufen
# 2021-05-13 12:17:54.898778: HTTP Error 405:
# ID /expose/128025542 entfernt.
# 2021-05-13 12:17:55.349606: HTTP Error 405:
# ID /expose/127985191 entfernt.
# 2021-05-13 12:17:57.498981: HTTP Error 405:
# ID /expose/128025273 entfernt.
# 2021-05-13 12:18:00.572057: HTTP Error 405:
# ID /expose/128025573 entfernt.
# 2021-05-13 12:18:02.059328: HTTP Error 405:
# ID /expose/127977067 entfernt.
# 2021-05-13 12:18:02.559937: HTTP Error 405:
# ID /expose/128025504 entfernt.
# 2021-05-13 12:18:03.038932: HTTP Error 405:
# ID /expose/128025633 entfernt.
# 2021-05-13 12:18:04.398099: HTTP Error 405:
# ID /expose/128025727 entfernt.
# 2021-05-13 12:18:05.719119: HTTP Error 405:
# ID /expose/128025533 entfernt.
# Exportiert CSV
# Loop 83 endet.
#
# Loop 84 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-84/wohnung-kaufen
# 2021-05-13 12:18:09.992561: HTTP Error 405:
# ID /expose/128024630 entfernt.
# 2021-05-13 12:18:10.547370: HTTP Error 405:
# ID /expose/127686866 entfernt.
# 2021-05-13 12:18:11.182798: HTTP Error 405:
# ID /expose/127465843 entfernt.
# 2021-05-13 12:18:11.839721: HTTP Error 405:
# ID /expose/128025063 entfernt.
# 2021-05-13 12:18:12.441812: HTTP Error 405:
# ID /expose/128024565 entfernt.
# 2021-05-13 12:18:13.149534: HTTP Error 405:
# ID /expose/128023845 entfernt.
# 2021-05-13 12:18:15.328432: HTTP Error 405:
# ID /expose/128024610 entfernt.
# 2021-05-13 12:18:15.982648: HTTP Error 405:
# ID /expose/128023713 entfernt.
# 2021-05-13 12:18:17.919214: HTTP Error 405:
# ID /expose/128024377 entfernt.
# 2021-05-13 12:18:18.542334: HTTP Error 405:
# ID /expose/128023998 entfernt.
# 2021-05-13 12:18:19.194821: HTTP Error 405:
# ID /expose/128024718 entfernt.
# 2021-05-13 12:18:19.989470: HTTP Error 405:
# ID /expose/128023768 entfernt.
# 2021-05-13 12:18:20.622750: HTTP Error 405:
# ID /expose/127959135 entfernt.
# 2021-05-13 12:18:23.652347: HTTP Error 405:
# ID /expose/128024881 entfernt.
# 2021-05-13 12:18:24.136464: HTTP Error 405:
# ID /expose/128024774 entfernt.
# Exportiert CSV
# Loop 84 endet.
#
# Loop 85 startet.
# 2021-05-13 12:18:24.635755: HTTP Error 405:
# Loop 86 startet.
# 2021-05-13 12:18:25.053216: HTTP Error 405:
# Loop 87 startet.
# 2021-05-13 12:18:25.475511: HTTP Error 405:
# Loop 88 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-88/wohnung-kaufen
# 2021-05-13 12:18:26.919092: HTTP Error 405:
# ID /expose/128023138 entfernt.
# 2021-05-13 12:18:28.543506: HTTP Error 405:
# ID /expose/128023209 entfernt.
# 2021-05-13 12:18:34.749649: HTTP Error 405:
# ID /expose/123204201 entfernt.
# 2021-05-13 12:18:36.435278: HTTP Error 405:
# ID /expose/128022932 entfernt.
# 2021-05-13 12:18:38.990971: HTTP Error 405:
# ID /expose/128022821 entfernt.
# 2021-05-13 12:18:42.036771: HTTP Error 405:
# ID /expose/128023105 entfernt.
# 2021-05-13 12:18:42.512147: HTTP Error 405:
# ID /expose/127921968 entfernt.
# 2021-05-13 12:18:42.979795: HTTP Error 405:
# ID /expose/127921835 entfernt.
# 2021-05-13 12:18:43.441855: HTTP Error 405:
# ID /expose/128023203 entfernt.
# Exportiert CSV
# Loop 88 endet.
#
# Loop 89 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-89/wohnung-kaufen
# 2021-05-13 12:18:45.785005: HTTP Error 405:
# ID /expose/128021283 entfernt.
# 2021-05-13 12:18:46.266090: HTTP Error 405:
# ID /expose/128022530 entfernt.
# 2021-05-13 12:18:46.735984: HTTP Error 405:
# ID /expose/128022179 entfernt.
# 2021-05-13 12:18:47.182666: HTTP Error 405:
# ID /expose/128021984 entfernt.
# 2021-05-13 12:18:48.378319: HTTP Error 405:
# ID /expose/128022562 entfernt.
# 2021-05-13 12:18:48.843898: HTTP Error 405:
# ID /expose/128022274 entfernt.
# 2021-05-13 12:18:50.971211: HTTP Error 405:
# ID /expose/128022147 entfernt.
# 2021-05-13 12:18:52.263506: HTTP Error 405:
# ID /expose/128021981 entfernt.
# 2021-05-13 12:18:52.723038: HTTP Error 405:
# ID /expose/128022025 entfernt.
# 2021-05-13 12:18:53.191146: HTTP Error 405:
# ID /expose/128022235 entfernt.
# 2021-05-13 12:18:55.443781: HTTP Error 405:
# ID /expose/128021889 entfernt.
# 2021-05-13 12:18:57.295246: HTTP Error 405:
# ID /expose/127955506 entfernt.
# 2021-05-13 12:19:01.007175: HTTP Error 405:
# ID /expose/128022266 entfernt.
# Exportiert CSV
# Loop 89 endet.
#
# Loop 90 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-90/wohnung-kaufen
# 2021-05-13 12:19:03.373467: HTTP Error 405:
# ID /expose/128021710 entfernt.
# 2021-05-13 12:19:03.804261: HTTP Error 405:
# ID /expose/128021751 entfernt.
# 2021-05-13 12:19:04.302820: HTTP Error 405:
# ID /expose/127993725 entfernt.
# 2021-05-13 12:19:05.535385: HTTP Error 405:
# ID /expose/128021384 entfernt.
# 2021-05-13 12:19:06.005937: HTTP Error 405:
# ID /expose/128021313 entfernt.
# 2021-05-13 12:19:06.489355: HTTP Error 405:
# ID /expose/128021826 entfernt.
# 2021-05-13 12:19:07.762547: HTTP Error 405:
# ID /expose/128021752 entfernt.
# 2021-05-13 12:19:08.243697: HTTP Error 405:
# ID /expose/128020020 entfernt.
# 2021-05-13 12:19:09.484423: HTTP Error 405:
# ID /expose/128020958 entfernt.
# 2021-05-13 12:19:10.887113: HTTP Error 405:
# ID /expose/128021365 entfernt.
# 2021-05-13 12:19:11.299942: HTTP Error 405:
# ID /expose/127993632 entfernt.
# 2021-05-13 12:19:11.702705: HTTP Error 405:
# ID /expose/128021329 entfernt.
# 2021-05-13 12:19:12.201648: HTTP Error 405:
# ID /expose/128021774 entfernt.
# 2021-05-13 12:19:13.531995: HTTP Error 405:
# ID /expose/128021729 entfernt.
# 2021-05-13 12:19:14.831208: HTTP Error 405:
# ID /expose/128021698 entfernt.
# Exportiert CSV
# Loop 90 endet.
#
# Loop 91 startet.
# 2021-05-13 12:19:15.328694: HTTP Error 405:
# Loop 92 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-92/wohnung-kaufen
# 2021-05-13 12:19:17.051212: HTTP Error 405:
# ID /expose/127859052 entfernt.
# 2021-05-13 12:19:18.317753: HTTP Error 405:
# ID /expose/128020581 entfernt.
# 2021-05-13 12:19:18.716943: HTTP Error 405:
# ID /expose/128020148 entfernt.
# 2021-05-13 12:19:19.187984: HTTP Error 405:
# ID /expose/128020619 entfernt.
# 2021-05-13 12:19:19.641949: HTTP Error 405:
# ID /expose/128019349 entfernt.
# 2021-05-13 12:19:20.085265: HTTP Error 405:
# ID /expose/128020606 entfernt.
# 2021-05-13 12:19:20.541749: HTTP Error 405:
# ID /expose/128020713 entfernt.
# 2021-05-13 12:19:21.013300: HTTP Error 405:
# ID /expose/128020683 entfernt.
# 2021-05-13 12:19:23.307330: HTTP Error 405:
# ID /expose/102236434 entfernt.
# 2021-05-13 12:19:23.787638: HTTP Error 405:
# ID /expose/125146901 entfernt.
# 2021-05-13 12:19:24.356442: HTTP Error 405:
# ID /expose/117028639 entfernt.
# 2021-05-13 12:19:26.698740: HTTP Error 405:
# ID /expose/128020558 entfernt.
# 2021-05-13 12:19:27.169455: HTTP Error 405:
# ID /expose/127996100 entfernt.
# 2021-05-13 12:19:28.546299: HTTP Error 405:
# ID /expose/91082914 entfernt.
# 2021-05-13 12:19:29.060928: HTTP Error 405:
# ID /expose/128020665 entfernt.
# Exportiert CSV
# Loop 92 endet.
#
# Loop 93 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-93/wohnung-kaufen
# 2021-05-13 12:19:30.735386: HTTP Error 405:
# ID /expose/128020035 entfernt.
# 2021-05-13 12:19:32.883999: HTTP Error 405:
# ID /expose/128020280 entfernt.
# 2021-05-13 12:19:35.167526: HTTP Error 405:
# ID /expose/128020083 entfernt.
# 2021-05-13 12:19:37.377070: HTTP Error 405:
# ID /expose/128020057 entfernt.
# 2021-05-13 12:19:38.730175: HTTP Error 405:
# ID /expose/128020448 entfernt.
# 2021-05-13 12:19:42.018701: HTTP Error 405:
# ID /expose/128020425 entfernt.
# 2021-05-13 12:19:42.428121: HTTP Error 405:
# ID /expose/128020228 entfernt.
# 2021-05-13 12:19:42.923259: HTTP Error 405:
# ID /expose/128020285 entfernt.
# 2021-05-13 12:19:43.320184: HTTP Error 405:
# ID /expose/128020362 entfernt.
# 2021-05-13 12:19:43.778788: HTTP Error 405:
# ID /expose/128020337 entfernt.
# Exportiert CSV
# Loop 93 endet.
#
# Loop 94 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-94/wohnung-kaufen
# 2021-05-13 12:19:46.103021: HTTP Error 405:
# ID /expose/128019426 entfernt.
# 2021-05-13 12:19:48.178411: HTTP Error 405:
# ID /expose/122391870 entfernt.
# 2021-05-13 12:19:49.618256: HTTP Error 405:
# ID /expose/126791658 entfernt.
# 2021-05-13 12:19:50.084206: HTTP Error 405:
# ID /expose/128019767 entfernt.
# 2021-05-13 12:19:51.313240: HTTP Error 405:
# ID /expose/128019713 entfernt.
# 2021-05-13 12:19:53.263027: HTTP Error 405:
# ID /expose/128019790 entfernt.
# 2021-05-13 12:19:53.767453: HTTP Error 405:
# ID /expose/128019341 entfernt.
# 2021-05-13 12:19:54.243791: HTTP Error 405:
# ID /expose/128019755 entfernt.
# 2021-05-13 12:19:54.660801: HTTP Error 405:
# ID /expose/128019896 entfernt.
# 2021-05-13 12:19:55.155841: HTTP Error 405:
# ID /expose/128019925 entfernt.
# 2021-05-13 12:19:55.623628: HTTP Error 405:
# ID /expose/123781549 entfernt.
# 2021-05-13 12:19:56.129150: HTTP Error 405:
# ID /expose/127972306 entfernt.
# 2021-05-13 12:19:56.529172: HTTP Error 405:
# ID /expose/128019660 entfernt.
# 2021-05-13 12:19:57.782471: HTTP Error 405:
# ID /expose/128019422 entfernt.
# 2021-05-13 12:19:58.202062: HTTP Error 405:
# ID /expose/124898234 entfernt.
# 2021-05-13 12:19:58.704681: HTTP Error 405:
# ID /expose/128019862 entfernt.
# 2021-05-13 12:19:59.164645: HTTP Error 405:
# ID /expose/128019748 entfernt.
# Exportiert CSV
# Loop 94 endet.
#
# Loop 95 startet.
# 2021-05-13 12:20:00.599889: HTTP Error 405:
# Loop 96 startet.
# 2021-05-13 12:20:01.086071: HTTP Error 405:
# Loop 97 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-97/wohnung-kaufen
# 2021-05-13 12:20:03.691758: HTTP Error 405:
# ID /expose/128016667 entfernt.
# 2021-05-13 12:20:04.235112: HTTP Error 405:
# ID /expose/128018334 entfernt.
# 2021-05-13 12:20:04.671390: HTTP Error 405:
# ID /expose/128018444 entfernt.
# 2021-05-13 12:20:05.193183: HTTP Error 405:
# ID /expose/128018245 entfernt.
# 2021-05-13 12:20:05.668142: HTTP Error 405:
# ID /expose/128004632 entfernt.
# 2021-05-13 12:20:06.202233: HTTP Error 405:
# ID /expose/128016678 entfernt.
# 2021-05-13 12:20:07.688892: HTTP Error 405:
# ID /expose/127988055 entfernt.
# 2021-05-13 12:20:08.968463: HTTP Error 405:
# ID /expose/128018237 entfernt.
# 2021-05-13 12:20:10.308153: HTTP Error 405:
# ID /expose/128017710 entfernt.
# 2021-05-13 12:20:10.760002: HTTP Error 405:
# ID /expose/128018200 entfernt.
# 2021-05-13 12:20:11.261047: HTTP Error 405:
# ID /expose/128018473 entfernt.
# 2021-05-13 12:20:11.719643: HTTP Error 405:
# ID /expose/127939074 entfernt.
# 2021-05-13 12:20:12.227478: HTTP Error 405:
# ID /expose/128018430 entfernt.
# 2021-05-13 12:20:12.674430: HTTP Error 405:
# ID /expose/128018256 entfernt.
# 2021-05-13 12:20:13.159237: HTTP Error 405:
# ID /expose/128018284 entfernt.
# Exportiert CSV
# Loop 97 endet.
#
# Loop 98 startet.
# 2021-05-13 12:20:14.550782: HTTP Error 405:
# Loop 99 startet.
# 2021-05-13 12:20:15.021166: HTTP Error 405:
# Loop 100 startet.
# 2021-05-13 12:20:15.565127: HTTP Error 405:
# Loop 101 startet.
# 2021-05-13 12:20:16.049452: HTTP Error 405:
# Loop 102 startet.
# 2021-05-13 12:20:16.557680: HTTP Error 405:
# Loop 103 startet.
# 2021-05-13 12:20:17.088555: HTTP Error 405:
# Loop 104 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-104/wohnung-kaufen
# 2021-05-13 12:20:19.439461: HTTP Error 405:
# ID /expose/128010525 entfernt.
# 2021-05-13 12:20:20.737685: HTTP Error 405:
# ID /expose/128010532 entfernt.
# 2021-05-13 12:20:22.182554: HTTP Error 405:
# ID /expose/128010526 entfernt.
# 2021-05-13 12:20:24.429055: HTTP Error 405:
# ID /expose/128010523 entfernt.
# 2021-05-13 12:20:25.091080: HTTP Error 405:
# ID /expose/128010534 entfernt.
# 2021-05-13 12:20:25.654623: HTTP Error 405:
# ID /expose/128010520 entfernt.
# 2021-05-13 12:20:26.174481: HTTP Error 405:
# ID /expose/128010539 entfernt.
# 2021-05-13 12:20:26.683174: HTTP Error 405:
# ID /expose/128010535 entfernt.
# 2021-05-13 12:20:28.077737: HTTP Error 405:
# ID /expose/128010528 entfernt.
# 2021-05-13 12:20:29.483403: HTTP Error 405:
# ID /expose/128010538 entfernt.
# 2021-05-13 12:20:29.888661: HTTP Error 405:
# ID /expose/128010530 entfernt.
# 2021-05-13 12:20:30.414226: HTTP Error 405:
# ID /expose/128010521 entfernt.
# 2021-05-13 12:20:30.928341: HTTP Error 405:
# ID /expose/128010524 entfernt.
# Exportiert CSV
# Loop 104 endet.
#
# Loop 105 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-105/wohnung-kaufen
# 2021-05-13 12:20:32.608795: HTTP Error 405:
# ID /expose/128010503 entfernt.
# 2021-05-13 12:20:33.050017: HTTP Error 405:
# ID /expose/128010511 entfernt.
# 2021-05-13 12:20:33.512901: HTTP Error 405:
# ID /expose/128010501 entfernt.
# 2021-05-13 12:20:38.915400: HTTP Error 405:
# ID /expose/128010507 entfernt.
# 2021-05-13 12:20:40.429863: HTTP Error 405:
# ID /expose/128010497 entfernt.
# 2021-05-13 12:20:43.553126: HTTP Error 405:
# ID /expose/128010510 entfernt.
# 2021-05-13 12:20:44.016335: HTTP Error 405:
# ID /expose/128010505 entfernt.
# 2021-05-13 12:20:46.649189: HTTP Error 405:
# ID /expose/128010504 entfernt.
# 2021-05-13 12:20:47.169836: HTTP Error 405:
# ID /expose/128010516 entfernt.
# Exportiert CSV
# Loop 105 endet.
#
# Loop 106 startet.
# 2021-05-13 12:20:47.671671: HTTP Error 405:
# Loop 107 startet.
# 2021-05-13 12:20:48.172836: HTTP Error 405:
# Loop 108 startet.
# 2021-05-13 12:20:48.666387: HTTP Error 405:
# Loop 109 startet.
# 2021-05-13 12:20:49.165163: HTTP Error 405:
# Loop 110 startet.
# ...
# Loop 1508 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1508/wohnung-kaufen
# Exportiert CSV
# Loop 1508 endet.
#
# Loop 1509 startet.
# 2021-05-13 16:24:24.985639: HTTP Error 405:
# Loop 1510 startet.
# 2021-05-13 16:24:25.548252: HTTP Error 405:
# Loop 1511 startet.
# 2021-05-13 16:24:26.085305: HTTP Error 405:
# Loop 1512 startet.
# 2021-05-13 16:24:26.621571: HTTP Error 405:
# Loop 1513 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1513/wohnung-kaufen
# Exportiert CSV
# Loop 1513 endet.
#
# Loop 1514 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1514/wohnung-kaufen
# Exportiert CSV
# Loop 1514 endet.
#
# Loop 1515 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1515/wohnung-kaufen
# Exportiert CSV
# Loop 1515 endet.
#
# Loop 1516 startet.
# 2021-05-13 16:24:29.862145: HTTP Error 405:
# Loop 1517 startet.
# 2021-05-13 16:24:30.342582: HTTP Error 405:
# Loop 1518 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1518/wohnung-kaufen
# Exportiert CSV
# Loop 1518 endet.
#
# Loop 1519 startet.
# 2021-05-13 16:24:31.749259: HTTP Error 405:
# Loop 1520 startet.
# 2021-05-13 16:24:32.277227: HTTP Error 405:
# Loop 1521 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1521/wohnung-kaufen
# Exportiert CSV
# Loop 1521 endet.
#
# Loop 1522 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1522/wohnung-kaufen
# Exportiert CSV
# Loop 1522 endet.
#
# Loop 1523 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1523/wohnung-kaufen
# Exportiert CSV
# Loop 1523 endet.
#
# Loop 1524 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1524/wohnung-kaufen
# Exportiert CSV
# Loop 1524 endet.
#
# Loop 1525 startet.
# 2021-05-13 16:24:37.444286: HTTP Error 405:
# Loop 1526 startet.
# 2021-05-13 16:24:37.963843: HTTP Error 405:
# Loop 1527 startet.
# 2021-05-13 16:24:38.500258: HTTP Error 405:
# Loop 1528 startet.
# 2021-05-13 16:24:38.976507: HTTP Error 405:
# Loop 1529 startet.
# 2021-05-13 16:24:39.543854: HTTP Error 405:
# Loop 1530 startet.
# 2021-05-13 16:24:40.056818: HTTP Error 405:
# Loop 1531 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1531/wohnung-kaufen
# Exportiert CSV
# Loop 1531 endet.
#
# Loop 1532 startet.
# 2021-05-13 16:24:41.469628: HTTP Error 405:
# Loop 1533 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1533/wohnung-kaufen
# Exportiert CSV
# Loop 1533 endet.
#
# Loop 1534 startet.
# 2021-05-13 16:24:42.933260: HTTP Error 405:
# Loop 1535 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1535/wohnung-kaufen
# Exportiert CSV
# Loop 1535 endet.
#
# Loop 1536 startet.
# 2021-05-13 16:24:44.465873: HTTP Error 405:
# Loop 1537 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1537/wohnung-kaufen
# Exportiert CSV
# Loop 1537 endet.
#
# Loop 1538 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1538/wohnung-kaufen
# Exportiert CSV
# Loop 1538 endet.
#
# Loop 1539 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1539/wohnung-kaufen
# Exportiert CSV
# Loop 1539 endet.
#
# Loop 1540 startet.
# 2021-05-13 16:24:47.566636: HTTP Error 405:
# Loop 1541 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1541/wohnung-kaufen
# Exportiert CSV
# Loop 1541 endet.
#
# Loop 1542 startet.
# 2021-05-13 16:24:48.992056: HTTP Error 405:
# Loop 1543 startet.
# 2021-05-13 16:24:49.572366: HTTP Error 405:
# Loop 1544 startet.
# 2021-05-13 16:24:50.067857: HTTP Error 405:
# Loop 1545 startet.
# 2021-05-13 16:24:50.574966: HTTP Error 405:
# Loop 1546 startet.
# 2021-05-13 16:24:51.091713: HTTP Error 405:
# Loop 1547 startet.
# 2021-05-13 16:24:51.650145: HTTP Error 405:
# Loop 1548 startet.
# 2021-05-13 16:24:52.213812: HTTP Error 405:
# Loop 1549 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1549/wohnung-kaufen
# Exportiert CSV
# Loop 1549 endet.
#
# Loop 1550 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1550/wohnung-kaufen
# Exportiert CSV
# Loop 1550 endet.
#
# Loop 1551 startet.
# 2021-05-13 16:24:54.734478: HTTP Error 405:
# Loop 1552 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1552/wohnung-kaufen
# Exportiert CSV
# Loop 1552 endet.
#
# Loop 1553 startet.
# 2021-05-13 16:24:56.147802: HTTP Error 405:
# Loop 1554 startet.
# 2021-05-13 16:24:56.737566: HTTP Error 405:
# Loop 1555 startet.
# 2021-05-13 16:24:57.284156: HTTP Error 405:
# Loop 1556 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1556/wohnung-kaufen
# Exportiert CSV
# Loop 1556 endet.
#
# Loop 1557 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1557/wohnung-kaufen
# Exportiert CSV
# Loop 1557 endet.
#
# Loop 1558 startet.
# 2021-05-13 16:24:59.757196: HTTP Error 405:
# Loop 1559 startet.
# 2021-05-13 16:25:00.277924: HTTP Error 405:
# Loop 1560 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1560/wohnung-kaufen
# Exportiert CSV
# Loop 1560 endet.
#
# Loop 1561 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1561/wohnung-kaufen
# Exportiert CSV
# Loop 1561 endet.
#
# Loop 1562 startet.
# 2021-05-13 16:25:02.418128: HTTP Error 405:
# Loop 1563 startet.
# 2021-05-13 16:25:02.858133: HTTP Error 405:
# Loop 1564 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1564/wohnung-kaufen
# Exportiert CSV
# Loop 1564 endet.
#
# Loop 1565 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1565/wohnung-kaufen
# Exportiert CSV
# Loop 1565 endet.
#
# Loop 1566 startet.
# 2021-05-13 16:25:05.071720: HTTP Error 405:
# Loop 1567 startet.
# 2021-05-13 16:25:05.626182: HTTP Error 405:
# Loop 1568 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1568/wohnung-kaufen
# Exportiert CSV
# Loop 1568 endet.
#
# Loop 1569 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1569/wohnung-kaufen
# Exportiert CSV
# Loop 1569 endet.
#
# Loop 1570 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1570/wohnung-kaufen
# Exportiert CSV
# Loop 1570 endet.
#
# Loop 1571 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1571/wohnung-kaufen
# Exportiert CSV
# Loop 1571 endet.
#
# Loop 1572 startet.
# 2021-05-13 16:25:09.618839: HTTP Error 405:
# Loop 1573 startet.
# 2021-05-13 16:25:10.182689: HTTP Error 405:
# Loop 1574 startet.
# 2021-05-13 16:25:10.681527: HTTP Error 405:
# Loop 1575 startet.
# 2021-05-13 16:25:11.249834: HTTP Error 405:
# Loop 1576 startet.
# 2021-05-13 16:25:11.797430: HTTP Error 405:
# Loop 1577 startet.
# 2021-05-13 16:25:12.392372: HTTP Error 405:
# Loop 1578 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1578/wohnung-kaufen
# Exportiert CSV
# Loop 1578 endet.
#
# Loop 1579 startet.
# 2021-05-13 16:25:13.888314: HTTP Error 405:
# Loop 1580 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1580/wohnung-kaufen
# Exportiert CSV
# Loop 1580 endet.
#
# Loop 1581 startet.
# 2021-05-13 16:25:15.301201: HTTP Error 405:
# Loop 1582 startet.
# 2021-05-13 16:25:15.851573: HTTP Error 405:
# Loop 1583 startet.
# 2021-05-13 16:25:16.450026: HTTP Error 405:
# Loop 1584 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1584/wohnung-kaufen
# Exportiert CSV
# Loop 1584 endet.
#
# Loop 1585 startet.
# 2021-05-13 16:25:17.843480: HTTP Error 405:
# Loop 1586 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1586/wohnung-kaufen
# Exportiert CSV
# Loop 1586 endet.
#
# Loop 1587 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1587/wohnung-kaufen
# Exportiert CSV
# Loop 1587 endet.
#
# Loop 1588 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1588/wohnung-kaufen
# Exportiert CSV
# Loop 1588 endet.
#
# Loop 1589 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1589/wohnung-kaufen
# Exportiert CSV
# Loop 1589 endet.
#
# Loop 1590 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1590/wohnung-kaufen
# Exportiert CSV
# Loop 1590 endet.
#
# Loop 1591 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1591/wohnung-kaufen
# Exportiert CSV
# Loop 1591 endet.
#
# Loop 1592 startet.
# 2021-05-13 16:25:23.791152: HTTP Error 405:
# Loop 1593 startet.
# 2021-05-13 16:25:24.270810: HTTP Error 405:
# Loop 1594 startet.
# 2021-05-13 16:25:24.831936: HTTP Error 405:
# Loop 1595 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1595/wohnung-kaufen
# Exportiert CSV
# Loop 1595 endet.
#
# Loop 1596 startet.
# 2021-05-13 16:25:26.260373: HTTP Error 405:
# Loop 1597 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1597/wohnung-kaufen
# Exportiert CSV
# Loop 1597 endet.
#
# Loop 1598 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1598/wohnung-kaufen
# Exportiert CSV
# Loop 1598 endet.
#
# Loop 1599 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1599/wohnung-kaufen
# Exportiert CSV
# Loop 1599 endet.
#
# Loop 1600 startet.
# 2021-05-13 16:25:29.603327: HTTP Error 405:
# Loop 1601 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1601/wohnung-kaufen
# Exportiert CSV
# Loop 1601 endet.
#
# Loop 1602 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1602/wohnung-kaufen
# Exportiert CSV
# Loop 1602 endet.
#
# Loop 1603 startet.
# 2021-05-13 16:25:31.769174: HTTP Error 405:
# Loop 1604 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1604/wohnung-kaufen
# Exportiert CSV
# Loop 1604 endet.
#
# Loop 1605 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1605/wohnung-kaufen
# Exportiert CSV
# Loop 1605 endet.
#
# Loop 1606 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1606/wohnung-kaufen
# Exportiert CSV
# Loop 1606 endet.
#
# Loop 1607 startet.
# 2021-05-13 16:25:35.048898: HTTP Error 405:
# Loop 1608 startet.
# 2021-05-13 16:25:35.607994: HTTP Error 405:
# Loop 1609 startet.
# 2021-05-13 16:25:36.182806: HTTP Error 405:
# Loop 1610 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1610/wohnung-kaufen
# Exportiert CSV
# Loop 1610 endet.
#
# Loop 1611 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1611/wohnung-kaufen
# Exportiert CSV
# Loop 1611 endet.
#
# Loop 1612 startet.
# 2021-05-13 16:25:38.657027: HTTP Error 405:
# Loop 1613 startet.
# 2021-05-13 16:25:39.156598: HTTP Error 405:
# Loop 1614 startet.
# 2021-05-13 16:25:39.682306: HTTP Error 405:
# Loop 1615 startet.
# 2021-05-13 16:25:40.257592: HTTP Error 405:
# Loop 1616 startet.
# 2021-05-13 16:25:40.805024: HTTP Error 405:
# Loop 1617 startet.
# 2021-05-13 16:25:41.350941: HTTP Error 405:
# Loop 1618 startet.
# 2021-05-13 16:25:41.818483: HTTP Error 405:
# Loop 1619 startet.
# 2021-05-13 16:25:42.322950: HTTP Error 405:
# Loop 1620 startet.
# 2021-05-13 16:25:42.841339: HTTP Error 405:
# Loop 1621 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1621/wohnung-kaufen
# Exportiert CSV
# Loop 1621 endet.
#
# Loop 1622 startet.
# 2021-05-13 16:25:44.160509: HTTP Error 405:
# Loop 1623 startet.
# 2021-05-13 16:25:44.715700: HTTP Error 405:
# Loop 1624 startet.
# 2021-05-13 16:25:45.254309: HTTP Error 405:
# Loop 1625 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1625/wohnung-kaufen
# Exportiert CSV
# Loop 1625 endet.
#
# Loop 1626 startet.
# 2021-05-13 16:25:47.059318: HTTP Error 405:
# Loop 1627 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1627/wohnung-kaufen
# Exportiert CSV
# Loop 1627 endet.
#
# Loop 1628 startet.
# 2021-05-13 16:25:48.711131: HTTP Error 405:
# Loop 1629 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1629/wohnung-kaufen
# Exportiert CSV
# Loop 1629 endet.
#
# Loop 1630 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1630/wohnung-kaufen
# Exportiert CSV
# Loop 1630 endet.
#
# Loop 1631 startet.
# 2021-05-13 16:25:50.969924: HTTP Error 405:
# Loop 1632 startet.
# 2021-05-13 16:25:51.565356: HTTP Error 405:
# Loop 1633 startet.
# 2021-05-13 16:25:52.073033: HTTP Error 405:
# Loop 1634 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1634/wohnung-kaufen
# Exportiert CSV
# Loop 1634 endet.
#
# Loop 1635 startet.
# 2021-05-13 16:25:55.036084: HTTP Error 405:
# Loop 1636 startet.
# 2021-05-13 16:25:55.556021: HTTP Error 405:
# Loop 1637 startet.
# 2021-05-13 16:25:56.272049: HTTP Error 405:
# Loop 1638 startet.
# 2021-05-13 16:25:56.834412: HTTP Error 405:
# Loop 1639 startet.
# 2021-05-13 16:25:57.410052: HTTP Error 405:
# Loop 1640 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1640/wohnung-kaufen
# Exportiert CSV
# Loop 1640 endet.
#
# Loop 1641 startet.
# 2021-05-13 16:25:58.857753: HTTP Error 405:
# Loop 1642 startet.
# 2021-05-13 16:25:59.478026: HTTP Error 405:
# Loop 1643 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1643/wohnung-kaufen
# Exportiert CSV
# Loop 1643 endet.
#
# Loop 1644 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1644/wohnung-kaufen
# Exportiert CSV
# Loop 1644 endet.
#
# Loop 1645 startet.
# 2021-05-13 16:26:01.926623: HTTP Error 405:
# Loop 1646 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1646/wohnung-kaufen
# Exportiert CSV
# Loop 1646 endet.
#
# Loop 1647 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1647/wohnung-kaufen
# Exportiert CSV
# Loop 1647 endet.
#
# Loop 1648 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1648/wohnung-kaufen
# Exportiert CSV
# Loop 1648 endet.
#
# Loop 1649 startet.
# Aktuelle Seite: https://www.immobilienscout24.de/Suche/S-2/P-1649/wohnung-kaufen
# Exportiert CSV
# Loop 1649 endet.
#
# End of scraping!
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-58394a02b942> in <module>
# ----> 1 scrape_immobili('wohnung-kaufen',1650)
#
# <ipython-input-2-81bcbd5a48c6> in scrape_immobili(type_house, max_pages)
#      55     for i in os.listdir()[2:-2]:
#      56         n = n + 1
# ---> 57         df = df.append(pd.read_csv(str(i),sep = ";" , decimal = "," , encoding = "utf-8" ))
#      58         print ( "passage" + str ( n ) )
#      59
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# OSError: Initializing from file failed

# %% [markdown]
# ### clear the dirctory before running the next function

# %%
scrape_immobili('haus-kaufen',2300)

# %% [markdown]
# # Note for Professor
# 1. since entire scraping would take over 18hrs we decided to scrape different pages saperately and merge the data together at the end to save time
#
# 2. The number of pages that was available to scrape was initially estimated roughly based on the number of results that was shown, later we did a binary search to find exact number of pages, this wasen't done using any code so we haven't included it. Approximation used ~ (No of search results)/20 (as every page shows only 20 results)
